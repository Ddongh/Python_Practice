# %% [markdown]
# # openCV

# %%
# %pip install opencv-python

# %%
import cv2
print(cv2.__version__)

# %%
import cv2

img1 = cv2.imread('dog.jpg')
img2 = cv2.imread('dog.jpg', 1)
img3 = cv2.imread('dog.jpg', cv2.IMREAD_GRAYSCALE)

cv2.imshow('Original', img1)
cv2.imshow('Original', img2)
cv2.imshow('GrayScale', img3)
cv2.waitKey(0) # 키 입력을 기다린다. ms단위(0 : 무한히 기다린다.)
cv2.destroyAllWindows()

# %%
import cv2

img1 = cv2.imread('dog.jpg')
img2 = cv2.imread('cat.jpg')
img3 = cv2.hconcat(img1, img2) # 이미지 합치기

#cv2.imshow('concat', img3)
cv2.waitKey(0) # 키 입력을 기다린다. ms단위(0 : 무한히 기다린다.)
cv2.destroyAllWindows()

# %%
import cv2

img1 = cv2.imread('dog.jpg')
img2 = cv2.imread('cat.jpg')
img3 = cv2.hconcat([img1, img2])

cv2.imshow('concat', img1)
cv2.waitKey(0) # 키 입력을 기다린다. ms단위(0 : 무한히 기다린다.)
cv2.destroyAllWindows()

cv2.imwrite('dog.png', img1) # 이미지를 다른 포맷으로 저장

# %%
import cv2

print(cv2.__version__)

# %%
import cv2
cap = cv2.VideoCapture(0)

while cap.isOpened():
    # 카메라 프레임 읽기
    success, frame = cap.read()
    if success :
        # 프레임 출력
        cv2.imshow('Camera Window', frame)
        
        # ESC 종료
        key = cv2.waitKey(1) & 0xFF
        if key == 27:
            break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
cap = cv2.VideoCapture(0)

width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
print('size : {0} X {1}'.format(width, height))

fourcc = cv2.VideoWriter_fourcc(*'XVID') # 코덱 지정
writer = cv2.VideoWriter('camtest.avi', fourcc, 24, (int(width), int(height)))

while cap.isOpened():
    success, frame = cap.read()
    if success:
        writer.write(frame) # 프레임 저장
        cv2.imshow('Video Window', frame)
        
        # ESC 종료
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break

cap.release()
writer.release()
cv2.destroyAllWindows()
# Out:
# size : 1280.0 X 720.0

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('dog.jpg', 1)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.show()

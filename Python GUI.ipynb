# %%
# %autosave 60

# %% [markdown]
# # Button

# %%
from tkinter import *
root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+1000+300") # 창 크기 & 위치 조절

btn1 = Button(root, text = "버튼1") # 버튼 생성
btn1.pack()

#root.resizable(False, False)
root.mainloop()

# %%
from tkinter import *
root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+1000+300") # 창 크기 & 위치 조절

btn2 = Button(root, padx = 20, pady = 20, text = "버튼2") # 버튼 padding 변경
btn2.pack()

#root.resizable(False, False)
root.mainloop()

# %%
from tkinter import *
root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+1000+300") # 창 크기 & 위치 조절

btn3 = Button(root, width = 10, height = 5, text = "버튼3") # 버튼 사이즈 변경
btn3.pack()

#root.resizable(False, False)
root.mainloop()

# %%
from tkinter import *
root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+1000+300") # 창 크기 & 위치 조절

btn4 = Button(root, width = 10, height = 5, fg = "red", bg = "blue", text = "버튼4") # 버튼 사이즈 변경
btn4.pack() 

#root.resizable(False, False)
root.mainloop()

# %%
from tkinter import *
root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+1000+300") # 창 크기 & 위치 조절

def btncmd():
    print('좋아요를 눌러주세요')

photo = PhotoImage(file = "jamsuham.png")
btn5 = Button(root, image = photo, command = btncmd) # 버튼 이미지 설정
                                                     # 버튼 클릭이벤트 발생 시 수행할 이벤트 핸들러
btn5.pack()

#root.resizable(False, False)
root.mainloop()

# %% [markdown]
# # Lable

# %%
from tkinter import *
root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+900+300") # 창 크기 & 위치 조절

# label1 = Label(root, text = "누구인가?") # 텍스트 입력
# label1.pack()


#root.resizable(False, False)
root.mainloop()

# %%
from tkinter import *
root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+900+300") # 창 크기 & 위치 조절

# label1 = Label(root, text = "누구인가?") # 텍스트 입력
# label1.pack()

# photo = PhotoImage(file = "jamsuham.png")
# label2 = Label(root, image = photo) # 이미지 입력
# label2.pack()

 label = Label(root, text = '최선을 다하자')
 label.pack()

#  def change1():
#      label3.config(text = "최선을 다할껄") # 이벤트 핸들러 함수(텍스트 변경)
#  btn1 = Button(root, text = "텍스트 변경", command = change1) # 버튼 생성, 이벤트 핸들러
#  btn1.pack()

def change():
    global photo
    photo = PhotoImage(file = "jamsuham.png") # 이벤트 핸들러 함수(이미지 변경)
    label.config(image = photo)
btn = Button(root, text = "이미지 변경", command = change) # 버튼 생성, 이벤트 핸들러
btn.pack()


#root.resizable(False, False)
root.mainloop()

# %% [markdown]
# # Text

# %%
from tkinter import *
root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+900+300") # 창 크기 & 위치 조절

txt = Text(root, width = 40, height = 20)
txt.insert(END, '글자를 입력하세요')
txt.pack()
#root.resizable(False, False)
root.mainloop()

# %% [markdown]
# # Entry

# %%
from tkinter import *
root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+900+300") # 창 크기 & 위치 조절

ent1 = Entry(root, width = 30)
ent1.insert(END, '아이디를 입력하세요')
ent1.pack()
ent2 = Entry(root, width = 30)
ent2.insert(END, '비밀번호를 입력하세요')
ent2.pack()

def btncmd():
    print(ent1.get())
    print(ent2.get())
btn = Button(root, text = '로그인', command = btncmd)
btn.pack()

#root.resizable(False, False)
root.mainloop()

# %%
from tkinter import *
root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+900+300") # 창 크기 & 위치 조절

ent1 = Entry(root, width = 30)
ent1.insert(END, '아이디를 입력하세요')
ent1.pack()
ent2 = Entry(root, width = 30)
ent2.insert(END, '비밀번호를 입력하세요')
ent2.pack()

def btncmd():
    ent1.delete(0, END)
    ent2.delete(0, END)
btn = Button(root, text = '삭제', command = btncmd)
btn.pack()

#root.resizable(False, False)
root.mainloop()

# %% [markdown]
# # List-Box

# %%
from tkinter import *
root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+900+300") # 창 크기 & 위치 조절

listbox = Listbox(root, selectmode = "single", height = 5)
listbox.insert(0, "Python")
listbox.insert(1, "C#")
listbox.insert(2, "MySQL")
listbox.insert(END, "JAVA")
listbox.insert(END, "HTML")
listbox.pack()

#root.resizable(False, False)
root.mainloop()

# %%
from tkinter import *
root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+900+300") # 창 크기 & 위치 조절

listbox = Listbox(root, selectmode = "extended", height = 0)
listbox.insert(0, "Python")
listbox.insert(1, "C#")
listbox.insert(2, "MySQL")
listbox.insert(END, "JAVA")
listbox.insert(END, "HTML")
listbox.pack()

def btncmd():
    listbox.delete(END)
btn = Button(root, text = '삭제', command = btncmd)
btn.pack()

#root.resizable(False, False)
root.mainloop()

# %%
from tkinter import *
root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+900+300") # 창 크기 & 위치 조절

listbox = Listbox(root, selectmode = "extended", height = 0)
listbox.insert(0, "Python")
listbox.insert(1, "C#")
listbox.insert(2, "MySQL")
listbox.insert(END, "JAVA")
listbox.insert(END, "HTML")
listbox.pack()

def btncmd():
    print(listbox.get(0,2))
btn = Button(root, text = '가져오기', command = btncmd)
btn.pack()

#root.resizable(False, False)
root.mainloop()

# %%
from tkinter import *
root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+900+300") # 창 크기 & 위치 조절

listbox = Listbox(root, selectmode = "extended", height = 0)
listbox.insert(0, "Python")
listbox.insert(1, "C#")
listbox.insert(2, "MySQL")
listbox.insert(END, "JAVA")
listbox.insert(END, "HTML")
listbox.pack()

def btncmd():
    print('선택한 항목 : ', listbox.curselection())
    print('항목 개수 : ', listbox.size())
btn = Button(root, text = '선택항목', command = btncmd)
btn.pack()

#root.resizable(False, False)
root.mainloop()

# %% [markdown]
# # Check-Box

# %%
from tkinter import *
root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+900+300") # 창 크기 & 위치 조절

chkclick = IntVar()
chkbox = Checkbutton(root, text = "오늘 하루 그만 보기", variable = chkclick)
chkbox.pack()

def btncmd():
    print('체크 상태 : ', chkclick.get())
btn = Button(root, text = '확인', command = btncmd)
btn.pack()

#root.resizable(False, False)
root.mainloop()

# %%
from tkinter import *
root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+900+300") # 창 크기 & 위치 조절

chkclick1 = IntVar()
chkclick2 = IntVar()

chkbox1 = Checkbutton(root, text = "오늘 하루 그만 보기", variable = chkclick1)
chkbox1.pack()
chkbox2 = Checkbutton(root, text = "일주일 동안 그만 보기", variable = chkclick2)
chkbox2.pack()

chkbox1.select()
chkbox2.deselect()

def btncmd():
    print('ch1 체크 상태 : ', chkclick1.get())
    print('ch2 체크 상태 : ', chkclick2.get())
btn = Button(root, text = '확인', command = btncmd)
btn.pack()

#root.resizable(False, False)
root.mainloop()

# %% [markdown]
# # Radio-Button

# %%
from tkinter import *
root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+900+300") # 창 크기 & 위치 조절

Label(root, text = '햄버거를 선택하세요').pack()
burger_var = StringVar()
btn_burger1 = Radiobutton(root, text = '불고기버거', value = '불고기버거', variable = burger_var)
btn_burger1.select()
btn_burger2 = Radiobutton(root, text = '치즈버거', value = '치즈버거', variable = burger_var)
btn_burger3 = Radiobutton(root, text = '더블버거', value = '더블버거', variable = burger_var)

btn_burger1.pack()
btn_burger2.pack()
btn_burger3.pack()

def btncmd():
    print(burger_var.get() + '를 선택하셨습니다.')
    
btn = Button(root, text = '주문', command = btncmd)
btn.pack()



#root.resizable(False, False)
root.mainloop()

# %% [markdown]
# # Combo-Box

# %%
import tkinter.ttk as ttk

from tkinter import *
root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+900+300") # 창 크기 & 위치 조절

dateVal = [str(i) + '일' for i in range(1, 32)]

combobox = ttk.Combobox(root, height = 5, values = dateVal, state = 'readonly')
combobox.current(0)
combobox.pack()
combobox.set('카드 결제일')

def btncmd():
    print(combobox.get() + '를 선택하셨습니다.')
    
btn = Button(root, text = '날짜', command = btncmd)
btn.pack()


#root.resizable(False, False)
root.mainloop()

# %% [markdown]
# # Progress_Bar

# %%
import tkinter.ttk as ttk

from tkinter import *
root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+900+300") # 창 크기 & 위치 조절

progressbar1 = ttk.Progressbar(root, maximum = 100, mode = 'indeterminate')
progressbar1.pack()

progressbar2 = ttk.Progressbar(root, maximum = 100, mode = 'determinate')
progressbar2.pack()

def btnStart():
    progressbar1.start(10)
    progressbar2.start(10)
    
btn1 = Button(root, text = '시작', command = btnStart)
btn1.pack()

def btnStop():
    progressbar1.stop()
    progressbar2.stop()
    
btn2 = Button(root, text = '정지', command = btnStop)
btn2.pack()

#root.resizable(False, False)
root.mainloop()

# %%
import tkinter.ttk as ttk
import time
import numpy as np

from tkinter import *
root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+900+300") # 창 크기 & 위치 조절

p_var = DoubleVar()
progressbar1 = ttk.Progressbar(root, maximum = 100, length = 150, variable = p_var)
progressbar1.pack()


def btnStart():
    for i in range(1, 101):
            time.sleep(0.1)
            p_var.set(i)
            progressbar1.update()
            #print(p_var.get(), end = "      ")
    
btn1 = Button(root, text = '시작', command = btnStart)
btn1.pack()

def btnStop():
    progressbar1.stop()
    
btn2 = Button(root, text = '정지', command = btnStop)
btn2.pack()

#root.resizable(False, False)
root.mainloop()

# %%
import tkinter.ttk as ttk
import time
import numpy as np

from tkinter import *
root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+900+300") # 창 크기 & 위치 조절

p_var = DoubleVar()
progressbar1 = ttk.Progressbar(root, maximum = 100, length = 150, variable = p_var)
progressbar1.pack()


def btnStart():
    for i in np.random.rand(100) * 100:
            time.sleep(0.1)
            p_var.set(i)
            progressbar1.update()
            #print(p_var.get(), end = "      ")
    
btn1 = Button(root, text = '시작', command = btnStart)
btn1.pack()

def btnStop():
    progressbar1.stop()
    
btn2 = Button(root, text = '정지', command = btnStop)
btn2.pack()

#root.resizable(False, False)
root.mainloop()

# %% [markdown]
# # Menu

# %%
import tkinter.ttk as ttk
import time
import numpy as np
from tkinter import *

root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+900+300") # 창 크기 & 위치 조절

def btncmd():
    print('New File')

mymenu = Menu(root)

menu_file = Menu(mymenu, tearoff = 0)
menu_file.add_command(label = 'New File', command = btncmd)
menu_file.add_command(label = 'New Window')
menu_file.add_separator()
menu_file.add_command(label = 'Open File')
menu_file.add_separator()
menu_file.add_command(label = 'Save All')
menu_file.add_separator()
menu_file.add_command(label = 'Exit', command = root.quit())

mymenu.add_cascade(label = 'File', menu = menu_file)

mymenu.add_cascade(label = 'Edit')
menu_view = Menu(mymenu, tearoff = 0)
menu_view.add_checkbutton(label = 'Show minimap')
menu_view.add_checkbutton(label = 'Show maxmap')
mymenu.add_cascade(label = 'View', menu = menu_view)

root.config(menu = mymenu)

#root.resizable(False, False)
root.mainloop()

# %% [markdown]
# # Message-Box

# %%
import tkinter.ttk as ttk
from tkinter import *
import tkinter.messagebox as msbox

root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+900+300") # 창 크기 & 위치 조절

def info():
    msbox.showinfo('알림', '정상적으로 예매 완료되었습니다.')
    
def warn():
    msbox.showwarning('경고', '해당 좌석은 매진되었습니다.')
    
def error():
    msbox.showerror('에러', '결제 오류가 발생했습니다.')
    
def okcancel():
    res = msbox.askokcancel('확인/취소', '해당 좌석은 유아동반석입니다. 예매하시겠습니까?')
    if (res == 1):
        print('예')
    elif (res == 0):
        print('아니오')
    else:
        print('취소')
Button(root, command = info, text = '알림').pack()
Button(root, command = warn, text = '경고').pack()
Button(root, command = error, text = '에러').pack()
Button(root, command = okcancel, text = '확인/취소').pack()





#root.resizable(False, False)
root.mainloop()
# Out:
# 예
# 아니오
# 아니오

# %% [markdown]
# # Grid

# %%
import tkinter.ttk as ttk
from tkinter import *
import tkinter.messagebox as msbox

root = Tk()
root.title("Python") # 타이틀 설정
root.geometry("500x600+900+300") # 창 크기 & 위치 조절

Button(root, text = 'F16', width = 5, height = 1).grid(row = 0, column = 0)
Button(root, text = 'F17', width = 5, height = 1).grid(row = 0, column = 1)
Button(root, text = 'F18', width = 5, height = 1).grid(row = 0, column = 2)
Button(root, text = 'F19', width = 5, height = 1).grid(row = 0, column = 3)

Button(root, text = 'clear', width = 5, height = 1).grid(row = 1, column = 0)
Button(root, text = '=', width = 5, height = 1).grid(row = 1, column = 1)
Button(root, text = '/', width = 5, height = 1).grid(row = 1, column = 2)
Button(root, text = '*', width = 5, height = 1).grid(row = 1, column = 3)

Button(root, text = '7', width = 5, height = 1).grid(row = 2, column = 0)
Button(root, text = '8', width = 5, height = 1).grid(row = 2, column = 1)
Button(root, text = '9', width = 5, height = 1).grid(row = 2, column = 2)
Button(root, text = '1', width = 5, height = 1).grid(row = 2, column = 3)

Button(root, text = '4', width = 5, height = 1).grid(row = 3, column = 0)
Button(root, text = '5', width = 5, height = 1).grid(row = 3, column = 1)
Button(root, text = '6', width = 5, height = 1).grid(row = 3, column = 2)
Button(root, text = '+', width = 5, height = 1).grid(row = 3, column = 3)

Button(root, text = '1', width = 5, height = 1).grid(row = 4, column = 0)
Button(root, text = '2', width = 5, height = 1).grid(row = 4, column = 1)
Button(root, text = '3', width = 5, height = 1).grid(row = 4, column = 2)
Button(root, text = 'Enter', width = 5, height = 1).grid(row = 4, column = 3)







#root.resizable(False, False)
root.mainloop()
